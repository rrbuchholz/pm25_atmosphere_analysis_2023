# %% [markdown]
# # Collect PurpleAir

# %% [markdown]
# Collects PurpleAir 2-minute data and hourly averages the data (with 90% or more data coverage) to write out raw hourly files files of PM2.5 values, temperature and humidity. Collects data from the old Thingspeak web API location, availble at the time of analysis, but no longer available.

# %% [markdown]
# ### Load python packages

# %%
import numpy as np
import pandas as pd
from pandas.tseries.offsets import DateOffset
import matplotlib.pyplot as plt
import datetime
from pathlib import Path                   # System agnostic paths

import requests # for url requests
from statistics import median # for median of array
import json # for json reading/writing
import time # for epoch timestamp
import csv # for writing csv files

# %% [markdown]
# ### Query webpage for station IDs

# %% [markdown]
# https://api.purpleair.com/

# %%
keys = {
        'api_key': '${user-access-code}', #for access to the api
        'nwlat': '38.9', #latmax
        'selat': '38.05', #latmin
        'nwlng': '-123.58', #lonmin
        'selng': '-122.24', #lonmax
        'location_type': '0', #outside
        # Thingspeak
        'fields': 'latitude,longitude,name,primary_id_a,primary_key_a,secondary_id_a,secondary_key_a,primary_id_b,primary_key_b,secondary_id_b,secondary_key_b,firmware_version'
        }
url = 'https://api.purpleair.com/v1/sensors?'
query_PurpleAir = requests.get(url, keys)
#query_PurpleAir = requests.get('https://api.purpleair.com/v1/sensors?api_key=201C6F2D-787A-11EC-B9BF-42010A800003&nwlat='+str(latmax)+'&selat='+str(latmin)+'&nwlng='+str(lonmin)+'&selng='+str(lonmax)+'&fields=latitude,longitude')

# %%
response_list = query_PurpleAir.json()
#response_list

# %%
#collect into pandas dataframe
data = pd.DataFrame(response_list.get('data'))
data.columns = response_list.get('fields')
data.index = data['sensor_index']
data
# Out:
#               sensor_index   latitude   longitude                  name  \
# sensor_index
# 131701              131701  38.315340 -122.507950           West Valley
# 132665              132665  38.540863 -123.096634             Mohrhardt
# 132747              132747  38.556640 -122.723070             MWSprings
# 133351              133351  38.680504 -123.429200       Sea Ranch Lodge
# 3184                  3184  38.305100 -122.288994                Imola6
# ...                    ...        ...         ...                   ...
# 125929              125929  38.296890 -122.660760            Uncle Andy
# 126435              126435  38.108265 -122.242744  Morningside Addition
# 126443              126443  38.397870 -122.821210          Petaluma Ave
# 127483              127483  38.295532 -122.246700   Stone Bridge School
# 128323              128323  38.692238 -122.853240    Munselle Vineyards
#
#               primary_id_a     primary_key_a  secondary_id_a  \
# sensor_index
# 131701             1528318  XB4WQ0GCMI0XZA5K         1528319
# 132665             1535288  4HQV93HTJQ4JOEWE         1535289
# 132747             1535541  BNJELGHG1M9TFUWE         1535542
# 133351             1538454  VACLTRPDB9KU8ELH         1538456
# 3184                328118  EBTHGX7UOPRJZFKO          328119
# ...                    ...               ...             ...
# 125929             1499092  6VNAQX1EYIOLA62Z         1499093
# 126435             1500815  6O4AU6LOQTTFQJ2Y         1500816
# 126443             1500831  SCDJU1N0361H2D52         1500832
# 127483             1505904  63HOLVZSBWTCLTIZ         1505905
# 128323             1508716  YRV2BCXOPDZGHKFJ         1508717
#
#                secondary_key_a  primary_id_b     primary_key_b  \
# sensor_index
# 131701        BPFA95I51WN5UGQJ       1528320  AC8WO1XSCNYM5JD8
# 132665        TKC1EHCKDTU4ZCSK       1535290  ITR8P78QB8070AW0
# 132747        XY71SAI77GKPEC13       1535543  KK0J6UNWB33FAZSW
# 133351        RJCDS3BM8HQW7D04       1538458  MM7XQS1EUOORIUFV
# 3184          TKZ3GCDS6SKMEO9H        328120  D79LMZE0FPIAAD1D
# ...                        ...           ...               ...
# 125929        IG4NWUAVKSI4Q8JD       1499094  5CDEDLQ5LJY8KLSU
# 126435        V1O9YX5J4IDRZETO       1500817  CLWU130VHVHCW4YS
# 126443        BKJ0G70OKYJM7J2N       1500833  QFOW3NG574UXQ4GW
# 127483        LR3MAA1WIH6V5KBD       1505906  BUOJL2L8F79729MQ
# 128323        22L0DPYI6EJR80WO       1508718  8CKP6SV8RZPK59ES
#
#               secondary_id_b   secondary_key_b firmware_version
# sensor_index
# 131701               1528321  KLA1VN2T34LVPIIO             7.00
# 132665               1535291  TUGPSQS9791BUGGV             7.00
# 132747               1535545  Q1EUG2O79ACOAL2R             7.00
# 133351               1538460  2BG4M7USX06ETQNY             7.00
# 3184                  328121  C7CIZG8VK024HP42            6.06a
# ...                      ...               ...              ...
# 125929               1499095  EGBSIQD4RN861O6E             7.00
# 126435               1500818  TT2IO4GYOFDUB0CD             7.00
# 126443               1500834  BDS86QQ33NCPG787             7.00
# 127483               1505907  RCZNYFY01L6A62O6             7.00
# 128323               1508719  WJE56TK8G020XSV4             7.00
#
# [692 rows x 13 columns]

# %% [markdown]
# ### Download and add PM2.5 data

# %% [markdown]
# Collect primary data for sensor A and B
#
# https://api.thingspeak.com

# %%
def extract_pm(df,header,key):
    
    if (key == 'key_a'):
        collect_subset = df.loc[:,('field6','field7', 'field2', 'field8')] #field2 and field 8 are PM2.5
        collect_subset.index = pd.to_datetime(df['created_at'])
        collect_subset.index.name = 'date (UTC)'
        collect_subset.rename({'field6': header['field6'], 
                               'field7': header['field7'], 
                               'field2': header['field2'], 
                               'field8': header['field8']}, 
                              axis='columns', inplace=True)
    elif (key == 'key_b'):
        collect_subset = df.loc[:,('field2', 'field8')] #field2 and field 8 are PM2.5
        collect_subset.index = pd.to_datetime(df['created_at'])
        collect_subset.index.name = 'date (UTC)'
        collect_subset.rename({'field2': header['field2'], 
                               'field8': header['field8']}, 
                              axis='columns', inplace=True)
    
    #night_subset = collect_subset[(collect_subset.index.hour==(3))|(collect_subset.index.hour==(4))].head()
    
    # Purple air raw data is 2-minute temporal resoultion
    # Convert to:
    # Hourly averages
    subset_hour = collect_subset.resample('H').mean()
    # Data coverage check
    # With a minimum of 90% of data available (if < 27 of a possible 30 points, np.NAN)
    subset_hour_count = collect_subset.resample('H').count()
    subset_hour = subset_hour.where(subset_hour_count >= 27)
    subset_hour_round = subset_hour.round(decimals=4)

    
    return(subset_hour_round)

# %%
def collect_station(data,sensor,starttime,endtime):
    #----------------------------------------
    # Need to download archived data from Thingspeak.
    #----------------------------------------
    # Primary Key A
    print(sensor)
    url = 'https://api.thingspeak.com/channels/{}/feeds.json'.format(data.loc[sensor, 'primary_id_a'])
    
    params = {
        'api_key': data.loc[sensor, 'primary_key_a'], # sensor API key
        'start': starttime, # start date YYYY-MM-DD%20HH:NN:SS
        'end': endtime, # end date YYYY-MM-DD%20HH:NN:SS
    }
    
    r = requests.get(url, params=params)
    
    #print(r.url) # print out full URL request with params
    data_raw = r.json()
    
    #print(data_raw)
    
    # collect the data
    try:
        df = pd.DataFrame(data_raw.get('feeds'), dtype=float)
        header = data_raw.get('channel')
        station_data_a = extract_pm(df,header,'key_a')
    except KeyError:
        print('DataFrame is empty for sensor A in this date! Skipping this sensor: ' + str(sensor))
        datelist = pd.date_range(start=starttime,end=endtime, freq="H")
        station_data_a = pd.DataFrame()
        #station_data_a.index = datelist

    
    #----------------------------------------
    # Primary Key B
    url = 'https://api.thingspeak.com/channels/{}/feeds.json'.format(data.loc[sensor, 'primary_id_b'])
    
    params = {
        'api_key': data.loc[sensor, 'primary_key_b'], # sensor API key
        'start': starttime, # start date YYYY-MM-DD%20HH:NN:SS
        'end': endtime, # end date YYYY-MM-DD%20HH:NN:SS
    }
    
    r = requests.get(url, params=params)
    data_raw = r.json()
    
    # collect the data
    try:
        df = pd.DataFrame(data_raw.get('feeds'), dtype=float)
        header = data_raw.get('channel')
        station_data_b = extract_pm(df,header,'key_b')
        station_data_b = station_data_b.rename(columns={"PM2.5 (ATM)": "PM2.5_b (ATM)", "PM2.5 (CF=1)": "PM2.5_b (CF=1)"}, errors="raise")
    except KeyError:
        print('DataFrame is empty empty for sensor B in this date! Skipping this sensor: ' + str(sensor))
        datelist = pd.date_range(start=starttime,end=endtime, freq="H")
        station_data_b = pd.DataFrame()
        
    final_station_data = pd.concat([station_data_a, station_data_b], axis=1)
    
    return(final_station_data)

# %% [markdown]
# ### Collect the sensor data and write to csv files

# %% [markdown]
# Need to set up date array in order to loop through collecting every 7 days

# %%
date_array = pd.date_range(start="2020-08-01 00:00:00",end="2020-11-1 00:00:00")
date_list = date_array[::7]

# %% [markdown]
# Process each sensor location separately

# %%
from datetime import timedelta

for sensor in data['sensor_index']:
    counter = 0
    station_meta = data.loc[sensor, ['sensor_index','name','latitude','longitude']]

    # Loop through days because of download limit
    for i in date_list:
        starttime = str(i)
        endtime = str(i + timedelta(days=7))
        
        collect_data = collect_station(data,sensor,starttime,endtime)
        
        if (counter == 0):
            final_data = collect_data
            counter += 1
        else:
            temp = final_data
            pm_data = collect_data
            final_data = pd.concat([temp, pm_data], axis=0)
    
    print(final_data)
    
    #final_data.replace(r'\s+( +\.)|#', np.nan, regex=True).replace('', np.nan)
    
    # replace spaces in naming
    station_meta[1]= station_meta[1].replace(' ', '')
    # replace forward slashes to avoid saving issues
    station_meta[1]= station_meta[1].replace('/', '_')

    csv_name = 'raw_download/PurpleAir_{}_{}_{}_{}.csv'.format(station_meta[0],station_meta[1],station_meta[2],station_meta[3])
    final_data.to_csv(csv_name, index=True, na_rep='NaN')
# Out:
# 131701
# DataFrame is empty for sensor A in this date! Skipping this sensor: 131701
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 131701
# 131701
# DataFrame is empty for sensor A in this date! Skipping this sensor: 131701
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 131701
# 131701
# DataFrame is empty for sensor A in this date! Skipping this sensor: 131701
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 131701
# 131701
# DataFrame is empty for sensor A in this date! Skipping this sensor: 131701
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 131701
# 131701
# DataFrame is empty for sensor A in this date! Skipping this sensor: 131701
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 131701
# 131701
# DataFrame is empty for sensor A in this date! Skipping this sensor: 131701
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 131701
# 131701
# DataFrame is empty for sensor A in this date! Skipping this sensor: 131701
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 131701
# 131701
# DataFrame is empty for sensor A in this date! Skipping this sensor: 131701
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 131701
# 131701
# DataFrame is empty for sensor A in this date! Skipping this sensor: 131701
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 131701
# 131701
# DataFrame is empty for sensor A in this date! Skipping this sensor: 131701
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 131701
# 131701
# DataFrame is empty for sensor A in this date! Skipping this sensor: 131701
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 131701
# 131701
# DataFrame is empty for sensor A in this date! Skipping this sensor: 131701
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 131701
# 131701
# DataFrame is empty for sensor A in this date! Skipping this sensor: 131701
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 131701
# 131701
# DataFrame is empty for sensor A in this date! Skipping this sensor: 131701
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 131701
# Empty DataFrame
# Columns: []
# Index: []
# 132665
# DataFrame is empty for sensor A in this date! Skipping this sensor: 132665
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 132665
# 132665
# DataFrame is empty for sensor A in this date! Skipping this sensor: 132665
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 132665
# 132665
# DataFrame is empty for sensor A in this date! Skipping this sensor: 132665
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 132665
# 132665
# DataFrame is empty for sensor A in this date! Skipping this sensor: 132665
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 132665
# 132665
# DataFrame is empty for sensor A in this date! Skipping this sensor: 132665
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 132665
# 132665
# DataFrame is empty for sensor A in this date! Skipping this sensor: 132665
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 132665
# 132665
# DataFrame is empty for sensor A in this date! Skipping this sensor: 132665
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 132665
# 132665
# DataFrame is empty for sensor A in this date! Skipping this sensor: 132665
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 132665
# 132665
# DataFrame is empty for sensor A in this date! Skipping this sensor: 132665
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 132665
# 132665
# DataFrame is empty for sensor A in this date! Skipping this sensor: 132665
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 132665
# 132665
# DataFrame is empty for sensor A in this date! Skipping this sensor: 132665
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 132665
# 132665
# DataFrame is empty for sensor A in this date! Skipping this sensor: 132665
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 132665
# 132665
# DataFrame is empty for sensor A in this date! Skipping this sensor: 132665
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 132665
# 132665
# DataFrame is empty for sensor A in this date! Skipping this sensor: 132665
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 132665
# Empty DataFrame
# Columns: []
# Index: []
# 132747
# DataFrame is empty for sensor A in this date! Skipping this sensor: 132747
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 132747
# 132747
# DataFrame is empty for sensor A in this date! Skipping this sensor: 132747
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 132747
# 132747
# DataFrame is empty for sensor A in this date! Skipping this sensor: 132747
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 132747
# 132747
# DataFrame is empty for sensor A in this date! Skipping this sensor: 132747
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 132747
# 132747
# DataFrame is empty for sensor A in this date! Skipping this sensor: 132747
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 132747
# 132747
# DataFrame is empty for sensor A in this date! Skipping this sensor: 132747
# DataFrame is empty empty for sensor B in this date! Skipping this sensor:
# ...                                ...       ...          ...           ...
# 2020-11-06 19:00:00+00:00      65.6667   33.9667       0.0753        0.0753
# 2020-11-06 20:00:00+00:00      65.1667   34.1333       0.1013        0.1013
# 2020-11-06 21:00:00+00:00      64.3667   37.5667       0.1400        0.1400
# 2020-11-06 22:00:00+00:00      63.0000   42.7333       0.0553        0.0553
# 2020-11-06 23:00:00+00:00      63.0667   42.3000       0.0397        0.0397
#
#                            PM2.5_b (ATM)  PM2.5_b (CF=1)
# date (UTC)
# 2020-08-01 00:00:00+00:00         2.6153          2.6153
# 2020-08-01 01:00:00+00:00            NaN             NaN
# 2020-08-01 02:00:00+00:00         3.6697          3.6697
# 2020-08-01 03:00:00+00:00         4.1547          4.1547
# 2020-08-01 04:00:00+00:00         5.0243          5.0243
# ...                                  ...             ...
# 2020-11-06 19:00:00+00:00         0.3453          0.3453
# 2020-11-06 20:00:00+00:00         0.4357          0.4357
# 2020-11-06 21:00:00+00:00         0.4343          0.4343
# 2020-11-06 22:00:00+00:00         0.2103          0.2103
# 2020-11-06 23:00:00+00:00         0.1223          0.1223
#
# [2353 rows x 6 columns]
# 134444
# DataFrame is empty for sensor A in this date! Skipping this sensor: 134444
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 134444
# 134444
# DataFrame is empty for sensor A in this date! Skipping this sensor: 134444
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 134444
# 134444
# DataFrame is empty for sensor A in this date! Skipping this sensor: 134444
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 134444
# 134444
# DataFrame is empty for sensor A in this date! Skipping this sensor: 134444
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 134444
# 134444
# DataFrame is empty for sensor A in this date! Skipping this sensor: 134444
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 134444
# 134444
# DataFrame is empty for sensor A in this date! Skipping this sensor: 134444
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 134444
# 134444
# DataFrame is empty for sensor A in this date! Skipping this sensor: 134444
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 134444
# 134444
# DataFrame is empty for sensor A in this date! Skipping this sensor: 134444
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 134444
# 134444
# DataFrame is empty for sensor A in this date! Skipping this sensor: 134444
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 134444
# 134444
# DataFrame is empty for sensor A in this date! Skipping this sensor: 134444
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 134444
# 134444
# DataFrame is empty for sensor A in this date! Skipping this sensor: 134444
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 134444
# 134444
# DataFrame is empty for sensor A in this date! Skipping this sensor: 134444
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 134444
# 134444
# DataFrame is empty for sensor A in this date! Skipping this sensor: 134444
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 134444
# 134444
# DataFrame is empty for sensor A in this date! Skipping this sensor: 134444
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 134444
# Empty DataFrame
# Columns: []
# Index: []
# 3631
# 3631
# 3631
# 3631
# 3631
# 3631
# 3631
# 3631
# 3631
# 3631
# 3631
# 3631
# 3631
# 3631
#                            Temperature  Humidity  PM2.5 (ATM)  PM2.5 (CF=1)  \
# date (UTC)
# 2020-08-01 00:00:00+00:00      86.7333   32.2333       1.6577        1.6577
# 2020-08-01 01:00:00+00:00      86.0000   32.7333       1.8657        1.8657
# 2020-08-01 02:00:00+00:00      81.2000   37.9667       1.9303        1.9303
# 2020-08-01 03:00:00+00:00      74.5000   44.6000       1.9707        1.9707
# 2020-08-01 04:00:00+00:00      70.0667   50.8000       1.9363        1.9363
# 2020-11-06 20:00:00+00:00      72.3667   27.2667       0.0513        0.0513
# 2020-11-06 21:00:00+00:00      70.7667   29.5333       0.0423        0.0423
# 2020-11-06 22:00:00+00:00      68.0667   35.3667       0.0483        0.0483
# 2020-11-06 23:00:00+00:00      67.9333   36.9000       0.0397        0.0397
#
#                            PM2.5_b (ATM)  PM2.5_b (CF=1)
# date (UTC)
# 2020-08-01 00:00:00+00:00         3.0397          3.0397
# 2020-08-01 01:00:00+00:00         4.1947          4.1947
# 2020-08-01 02:00:00+00:00         3.7923          3.7923
# 2020-08-01 03:00:00+00:00         3.8080          3.8080
# 2020-08-01 04:00:00+00:00         3.9583          3.9583
# ...                                  ...             ...
# 2020-11-06 19:00:00+00:00         0.1350          0.1350
# 2020-11-06 20:00:00+00:00         0.0670          0.0670
# 2020-11-06 21:00:00+00:00         0.0940          0.0940
# 2020-11-06 22:00:00+00:00         0.1267          0.1267
# 2020-11-06 23:00:00+00:00         0.0890          0.0890
#
# [2353 rows x 6 columns]
# 8034
# 8034
# 8034
# 8034
# 8034
# 8034
# 8034
# 8034
# 8034
# 8034
# 8034
# 8034
# 8034
# 8034
#                            Temperature  Humidity  PM2.5 (ATM)  PM2.5 (CF=1)  \
# date (UTC)
# 2020-08-01 00:00:00+00:00      96.9000   13.8667       5.5960        5.5960
# 2020-08-01 01:00:00+00:00      93.2667   15.3000       5.4137        5.4137
# 2020-08-01 02:00:00+00:00      88.9667   19.4333       4.9973        4.9973
# 2020-08-01 03:00:00+00:00      82.6000   23.7333       4.6310        4.6310
# 2020-08-01 04:00:00+00:00      77.3000   26.7667       4.0527        4.0527
# ...                                ...       ...          ...           ...
# 2020-11-06 19:00:00+00:00      57.1667   38.7667       0.0367        0.0367
# 2020-11-06 20:00:00+00:00      59.2333   37.6667       0.0023        0.0023
# 2020-11-06 21:00:00+00:00      57.8000   40.3000       0.0300        0.0300
# 2020-11-06 22:00:00+00:00      57.8000   41.0667       0.0347        0.0347
# 2020-11-06 23:00:00+00:00      56.2333   45.1000       0.0687        0.0687
#
#                            PM2.5_b (ATM)  PM2.5_b (CF=1)
# date (UTC)
# 2020-08-01 00:00:00+00:00         4.6900          4.6900
# 2020-08-01 01:00:00+00:00         4.5433          4.5433
# 2020-08-01 02:00:00+00:00         4.1873          4.1873
# 2020-08-01 03:00:00+00:00         3.7750          3.7750
# 2020-08-01 04:00:00+00:00         3.3367          3.3367
# ...                                  ...             ...
# 2020-11-06 19:00:00+00:00         0.0030          0.0030
# 2020-11-06 20:00:00+00:00         0.0000          0.0000
# 2020-11-06 21:00:00+00:00         0.0000          0.0000
# 2020-11-06 22:00:00+00:00         0.0000          0.0000
# 2020-11-06 23:00:00+00:00         0.0030          0.0030
#
# [2352 rows x 6 columns]
# 8062
# 8062
# 8062
# 8062
# 8062
# 8062
# 8062
# 8062
# 8062
# 8062
# 8062
# 8062
# 8062
# 8062
#                            Temperature  Humidity  PM2.5 (ATM)  PM2.5 (CF=1)  \
# date (UTC)
# 2020-08-01 00:00:00+00:00     103.9333   18.3667       3.5747        3.5747
# 2020-08-01 01:00:00+00:00          NaN       NaN          NaN           NaN
# 2020-08-01 02:00:00+00:00      94.2667   24.4000       3.9833        3.9833
# 2020-08-01 03:00:00+00:00      90.2667   23.4333       3.8013        3.8013
# 2020-08-01 04:00:00+00:00      86.7000   25.1333       4.5987        4.5987
# ...                                ...       ...          ...           ...
# 2020-11-06 19:00:00+00:00      64.2333   30.5000       0.0040        0.0040
# 2020-11-06 20:00:00+00:00      64.9333   32.1000       0.0113        0.0113
# 2020-11-06 21:00:00+00:00      64.8333   32.1000       0.0000        0.0000
# 2020-11-06 22:00:00+00:00      65.4000   33.6667       0.0000        0.0000
# 2020-11-06 23:00:00+00:00      64.4000   36.1667       0.0057        0.0057
#
#                            PM2.5_b (ATM)  PM2.5_b (CF=1)
# date (UTC)
# 2020-08-01 00:00:00+00:00         5.1930          5.1930
# 2020-08-01 01:00:00+00:00            NaN             NaN
# 2020-08-01 02:00:00+00:00         4.8573          4.8573
# 2020-08-01 03:00:00+00:00         4.8520          4.8520
# 2020-08-01 04:00:00+00:00         5.7623          5.7623
# ...                                  ...             ...
# 2020-11-06 19:00:00+00:00         0.0117          0.0117
# 2020-11-06 20:00:00+00:00         0.0053          0.0053
# 2020-11-06 21:00:00+00:00         0.0000          0.0000
# 2020-11-06 22:00:00+00:00         0.0057          0.0057
# 2020-11-06 23:00:00+00:00         0.0093          0.0093
#
# [2352 rows x 6 columns]
# 8124
# DataFrame is empty for sensor A in this date! Skipping this sensor: 8124
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 8124
# 8124
# DataFrame is empty for sensor A in this date! Skipping this sensor: 8124
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 8124
# 8124
# DataFrame is empty for sensor A in this date! Skipping this sensor: 8124
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 8124
# 8124
# DataFrame is empty for sensor A in this date! Skipping this sensor: 8124
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 8124
# 8124
# DataFrame is empty for sensor A in this date! Skipping this sensor: 8124
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 8124
# 8124
# DataFrame is empty for sensor A in this date! Skipping this sensor: 8124
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 8124
# 8124
# DataFrame is empty for sensor A in this date! Skipping this sensor: 8124
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 8124
# 8124
# DataFrame is empty for sensor A in this date! Skipping this sensor: 8124
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 8124
# 8124
# DataFrame is empty for sensor A in this date! Skipping this sensor: 8124
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 8124
# 8124
# DataFrame is empty for sensor A in this date! Skipping this sensor: 8124
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 8124
# 8124
# DataFrame is empty for sensor A in this date! Skipping this sensor: 8124
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 8124
# 8124
# DataFrame is empty for sensor A in this date! Skipping this sensor: 8124
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 8124
# 8124
# DataFrame is empty for sensor A in this date! Skipping this sensor: 8124
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 8124
# 8124
# DataFrame is empty for sensor A in this date! Skipping this sensor: 8124
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 8124
# Empty DataFrame
# Columns: []
# Index: []
# 140636
# DataFrame is empty for sensor A in this date! Skipping this sensor: 140636
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 140636
# 140636
# DataFrame is empty for sensor A in this date! Skipping this sensor: 140636
# ...
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125501
# 125501
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125501
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125501
# 125501
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125501
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125501
# 125501
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125501
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125501
# 125501
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125501
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125501
# 125501
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125501
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125501
# 125501
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125501
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125501
# 125501
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125501
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125501
# 125501
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125501
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125501
# 125501
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125501
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125501
# 125501
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125501
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125501
# 125501
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125501
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125501
# 125501
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125501
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125501
# Empty DataFrame
# Columns: []
# Index: []
# 125917
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125917
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125917
# 125917
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125917
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125917
# 125917
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125917
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125917
# 125917
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125917
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125917
# 125917
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125917
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125917
# 125917
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125917
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125917
# 125917
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125917
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125917
# 125917
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125917
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125917
# 125917
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125917
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125917
# 125917
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125917
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125917
# 125917
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125917
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125917
# 125917
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125917
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125917
# 125917
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125917
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125917
# 125917
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125917
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125917
# Empty DataFrame
# Columns: []
# Index: []
# 125929
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125929
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125929
# 125929
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125929
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125929
# 125929
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125929
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125929
# 125929
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125929
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125929
# 125929
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125929
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125929
# 125929
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125929
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125929
# 125929
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125929
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125929
# 125929
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125929
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125929
# 125929
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125929
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125929
# 125929
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125929
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125929
# 125929
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125929
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125929
# 125929
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125929
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125929
# 125929
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125929
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125929
# 125929
# DataFrame is empty for sensor A in this date! Skipping this sensor: 125929
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 125929
# Empty DataFrame
# Columns: []
# Index: []
# 126435
# DataFrame is empty for sensor A in this date! Skipping this sensor: 126435
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 126435
# 126435
# DataFrame is empty for sensor A in this date! Skipping this sensor: 126435
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 126435
# 126435
# DataFrame is empty for sensor A in this date! Skipping this sensor: 126435
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 126435
# 126435
# DataFrame is empty for sensor A in this date! Skipping this sensor: 126435
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 126435
# 126435
# DataFrame is empty for sensor A in this date! Skipping this sensor: 126435
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 126435
# 126435
# DataFrame is empty for sensor A in this date! Skipping this sensor: 126435
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 126435
# 126435
# DataFrame is empty for sensor A in this date! Skipping this sensor: 126435
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 126435
# 126435
# DataFrame is empty for sensor A in this date! Skipping this sensor: 126435
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 126435
# 126435
# DataFrame is empty for sensor A in this date! Skipping this sensor: 126435
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 126435
# 126435
# DataFrame is empty for sensor A in this date! Skipping this sensor: 126435
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 126435
# 126435
# DataFrame is empty for sensor A in this date! Skipping this sensor: 126435
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 126435
# 126435
# DataFrame is empty for sensor A in this date! Skipping this sensor: 126435
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 126435
# 126435
# DataFrame is empty for sensor A in this date! Skipping this sensor: 126435
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 126435
# 126435
# DataFrame is empty for sensor A in this date! Skipping this sensor: 126435
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 126435
# Empty DataFrame
# Columns: []
# Index: []
# 126443
# DataFrame is empty for sensor A in this date! Skipping this sensor: 126443
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 126443
# 126443
# DataFrame is empty for sensor A in this date! Skipping this sensor: 126443
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 126443
# 126443
# DataFrame is empty for sensor A in this date! Skipping this sensor: 126443
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 126443
# 126443
# DataFrame is empty for sensor A in this date! Skipping this sensor: 126443
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 126443
# 126443
# DataFrame is empty for sensor A in this date! Skipping this sensor: 126443
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 126443
# 126443
# DataFrame is empty for sensor A in this date! Skipping this sensor: 126443
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 126443
# 126443
# DataFrame is empty for sensor A in this date! Skipping this sensor: 126443
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 126443
# 126443
# DataFrame is empty for sensor A in this date! Skipping this sensor: 126443
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 126443
# 126443
# DataFrame is empty for sensor A in this date! Skipping this sensor: 126443
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 126443
# 126443
# DataFrame is empty for sensor A in this date! Skipping this sensor: 126443
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 126443
# 126443
# DataFrame is empty for sensor A in this date! Skipping this sensor: 126443
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 126443
# 126443
# DataFrame is empty for sensor A in this date! Skipping this sensor: 126443
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 126443
# 126443
# DataFrame is empty for sensor A in this date! Skipping this sensor: 126443
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 126443
# 126443
# DataFrame is empty for sensor A in this date! Skipping this sensor: 126443
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 126443
# Empty DataFrame
# Columns: []
# Index: []
# 127483
# DataFrame is empty for sensor A in this date! Skipping this sensor: 127483
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 127483
# 127483
# DataFrame is empty for sensor A in this date! Skipping this sensor: 127483
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 127483
# 127483
# DataFrame is empty for sensor A in this date! Skipping this sensor: 127483
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 127483
# 127483
# DataFrame is empty for sensor A in this date! Skipping this sensor: 127483
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 127483
# 127483
# DataFrame is empty for sensor A in this date! Skipping this sensor: 127483
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 127483
# 127483
# DataFrame is empty for sensor A in this date! Skipping this sensor: 127483
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 127483
# 127483
# DataFrame is empty for sensor A in this date! Skipping this sensor: 127483
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 127483
# 127483
# DataFrame is empty for sensor A in this date! Skipping this sensor: 127483
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 127483
# 127483
# DataFrame is empty for sensor A in this date! Skipping this sensor: 127483
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 127483
# 127483
# DataFrame is empty for sensor A in this date! Skipping this sensor: 127483
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 127483
# 127483
# DataFrame is empty for sensor A in this date! Skipping this sensor: 127483
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 127483
# 127483
# DataFrame is empty for sensor A in this date! Skipping this sensor: 127483
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 127483
# 127483
# DataFrame is empty for sensor A in this date! Skipping this sensor: 127483
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 127483
# 127483
# DataFrame is empty for sensor A in this date! Skipping this sensor: 127483
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 127483
# Empty DataFrame
# Columns: []
# Index: []
# 128323
# DataFrame is empty for sensor A in this date! Skipping this sensor: 128323
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 128323
# 128323
# DataFrame is empty for sensor A in this date! Skipping this sensor: 128323
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 128323
# 128323
# DataFrame is empty for sensor A in this date! Skipping this sensor: 128323
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 128323
# 128323
# DataFrame is empty for sensor A in this date! Skipping this sensor: 128323
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 128323
# 128323
# DataFrame is empty for sensor A in this date! Skipping this sensor: 128323
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 128323
# 128323
# DataFrame is empty for sensor A in this date! Skipping this sensor: 128323
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 128323
# 128323
# DataFrame is empty for sensor A in this date! Skipping this sensor: 128323
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 128323
# 128323
# DataFrame is empty for sensor A in this date! Skipping this sensor: 128323
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 128323
# 128323
# DataFrame is empty for sensor A in this date! Skipping this sensor: 128323
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 128323
# 128323
# DataFrame is empty for sensor A in this date! Skipping this sensor: 128323
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 128323
# 128323
# DataFrame is empty for sensor A in this date! Skipping this sensor: 128323
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 128323
# 128323
# DataFrame is empty for sensor A in this date! Skipping this sensor: 128323
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 128323
# 128323
# DataFrame is empty for sensor A in this date! Skipping this sensor: 128323
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 128323
# 128323
# DataFrame is empty for sensor A in this date! Skipping this sensor: 128323
# DataFrame is empty empty for sensor B in this date! Skipping this sensor: 128323
# Empty DataFrame
# Columns: []
# Index: []
